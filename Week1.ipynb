# %% [markdown]
# <a href="https://colab.research.google.com/github/riobagas02/PCVK_Ganjil_2024/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google .colab. patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib. pylab as pit

# %%
# membuat list untuk menyimpan url dari beberapa image

urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://i.pinimg.com/736x/1c/9d/0e/1c9d0e38cb7aa59ef030bebd711f5e8f.jpg"]

# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  try:
    image   = io.imread(url)
    image   = cv.resize(image, (0,0), fx=0.5, fy=0.5)
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    final_frame = cv.hconcat((image, image_2))
    cv2_imshow(final_frame)
    print('\n')
  except Exception as e:
    print(f"Error loading image from {url}: {e}")
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=736x207>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x Lebar = " ,tinggi, "x" , lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x Lebar =  207 x 368
# <PIL.Image.Image image mode=RGB size=368x207>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3 [int((tinggi)/2),y] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=736x207>

# %% [markdown]
# **Pertanyaan**
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#   image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
# 4. Perhatikan potongan kode progam berikut :
#       #membuat garis horizontal ditengah image
#       for y in range (lebar):
#       image_3 [int((tinggi)/2),y] = [255,255,255]
#
#   Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!

# %% [markdown]
# **Jawaban**
#
# 1. Google Colab dapat diakses secara gratis melalui browser web, tanpa melakukan instalasi software di komputer lokal. Sehingga memudahkan untuk memulai dan mengikuti praktikum tanpa memerlukan spesifikasi hardware tertentu.
# 2. Tidak semua library tersebut digunakan pada praktikum sesi ini. Penggunaan library bergantung pada tujuan dan tugas spesifik yang ingin dicapai.
#
# Sebagai contoh, jika fokusnya hanya pada membaca gambar dari URL dan menampilkannya, maka library skimage.io dan google.colab.patches.cv2_imshow cukup.
#
# 3. Potongan kode image = cv.resize(image, (0,0), fx=0.5, fy=0.5) berfungsi untuk mengubah ukuran gambar.
#
# (0, 0) menentukan ukuran baru dalam piksel.
# fx=0.5 dan fy=0.5 adalah faktor skala.
# Nilai 0.5 berarti gambar akan diperkecil menjadi setengah dari ukuran aslinya, baik untuk lebar (fx) maupun tinggi (fy).
#
# 4. Kode [255, 255, 255] dalam konteks ini merepresentasikan warna putih dalam model warna RGB.
#
# 5. Piksel adalah unit dasar pembentuk gambar. Resolusi gambar menentukan seberapa banyak piksel yang digunakan untuk membentuk gambar tersebut.
#
# Resolusi tinggi = banyak piksel = detail dan tajam.
# Resolusi rendah = sedikit piksel = kurang detail dan mungkin buram.

# %% [markdown]
# # **TUGAS**

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (tinggi):
  image_3 [x,int((lebar)/2)] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=736x207>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

slope = tinggi / lebar

for x in range(tinggi):
  for y in range(lebar):
    if abs(x - slope * y) < 1 or abs(x - (tinggi - slope * y)) < 1 :
      image_3[x, y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=736x207>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

start_x = int(lebar * 0.3)
end_x = int(lebar * 0.45)

for y in range(start_x, end_x):
  image_3[int(tinggi/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=736x207>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

start_point = (int(lebar * 0.2), int(tinggi * 0.2))
end_point = (int(lebar * 0.5), int(tinggi * 0.))

cv.rectangle(image_3, start_point, end_point, (255, 255, 255), thickness=-1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=736x207>

# %% [markdown]
# ## **Tugas Kelompok 8**

# %% [markdown]
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7202e27b-7a12-4bcd-ad2e-ba68cc8b8045" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7202e27b-7a12-4bcd-ad2e-ba68cc8b8045">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# Akses file image KTP
img = cv2.imread('/content/KTP.jpg')

# Resize image
image = cv2.resize(img, (0, 0), fx=0.5, fy=0.5)

# Konversi BGR ke RGB sebelum menampilkan dengan Matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Buat figure untuk menampilkan dua gambar
plt.figure(figsize=(10,5))

# Gambar pertama: tanpa axis rgb
plt.subplot(1, 2, 1)
plt.imshow(image_rgb)
plt.axis('off')  # Hilangkan axis
plt.title('Gambar tanpa Axis RGB')

# Gambar kedua: dengan axis gbr
plt.subplot(1, 2, 2)
plt.imshow(image)
plt.axis('on')  # Tampilkan axis
plt.title('Gambar dengan Axis GBR')

# Tampilkan gambar
plt.show()

# %% [markdown]
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa
# konversi pada opencv

# %% [markdown]
# Jawab
#
# OpenCV menggunakan format warna BGR, sementara Matplotlib menggunakan RGB. Karena perbedaan ini, konversi dari BGR ke RGB diperlukan saat menampilkan gambar yang dibaca oleh OpenCV menggunakan Matplotlib, agar warna terlihat benar. Jika gambar hanya ditampilkan dengan OpenCV, konversi tidak diperlukan.

# %% [markdown]
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut
#
# Kelompok 8 tutup bagian kabupaten
# dan tanggal dikeluarkan KTP yang ada dibagian bawah foto.

# %%
plt.subplot(1, 2, 2)
plt.imshow(image_rgb)
plt.axis('on')

plt.show()

# %%
copy = np.copy(image)
copy = cv.cvtColor(copy, cv.COLOR_BGR2RGB)
for y in range(365,465):
  for x in range(225, 245):
    copy[x,y] = [255,,0]

for y in range(200, 310):
  for x in range(30, 45):
    copy[x,y] = [0,255,0]
plt.imshow(copy)
